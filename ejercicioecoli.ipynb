# %% [markdown]
# calcular una cepa de e coli tiene una tasa de crecimiento tal que un individuo se duplica cada 30 minutos.
#
# a) calcular en cuanto tiempo esta cepa llenaria el volumen de la tierra (considerandola como una esfera hueca)
#
# b) cubriria la superficie de la tierra
#
# c) repite el calculo para una tasa de crecimiento:
#  se duplica cada hora
#  se duplica cada 1/4 de hora

# %%
print("radio de la tierra en km:",6.371)
print("volumen de la tierra:",(4/3*(3.1416)*(r**3)))
print("volumen de e.coli",0.25e-6)
# Out:
#   Cell In[36], line 2
#     print("volumen de la tierra:",(4/3*(3.1416)*(r**3))
#          ^
# SyntaxError: '(' was never closed

# %%
n=((6371e3)**3)/((0.5e-6)**3)

# %%
n
# Out:
# 2.0687728224880002e+39

# %%
import math as mt

# %%
mt.log2(n)
# Out:
# 130.6039709282774

# %%
t=n

# %%
t
# Out:
# 2.0687728224880002e+39

# %%
th=(t/2)

# %%
th
# Out:
# 1.0343864112440001e+39

# %%
td=(th/48)

# %%
td
# Out:
# 2.1549716900916667e+37

# %%
print(td)
# Out:
# 2.1549716900916667e+37
